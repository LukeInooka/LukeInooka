# %%
def valid(number:int)->int:
    lis = list(str(number))
    check_digit = lis[-1]
    print(lis)
    final = 0
    for i,num in enumerate(lis):
        if i % 2 != 0:
            a = str(int(num)*2)
            final += int(a[0])
            if len(a) > 1:
                final += int(a[1])
        else:
            final += int(num)
    if final % 10 == 0:
        return True
    else:
        return False

valid(12345674)
# c=0
# for i in range(1000000000000000,10000000000000000):
#      if valid(i):
#          c+=1
#          print(c,i)
# print(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13736/1017099024.py in <module>
#      17         return False
#      18
# ---> 19 valid(12345674)
#      20 # c=0
#      21 # for i in range(1000000000000000,10000000000000000):
#
# ~\AppData\Local\Temp/ipykernel_13736/1017099024.py in valid(number)
#       1 def valid(number:int)->int:
# ----> 2     lis = list(number)
#       3     check_digit = lis[-1]
#       4     print(lis)
#       5     final = 0
#
# TypeError: 'int' object is not iterable

# %%
length = 1001
l = [0]* length
def coins(lis):
    for i in range(1,length):
        count = 0
        for index,num in enumerate(lis):
            if count == i:
                lis[index] = 1-num
                count = 0
            else:
                count+=1
    return lis
coins(l)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20128/1788599657.py in <module>
#      11                 count+=1
#      12     return lis
# ---> 13 coins(l)
#      14
#
# ~\AppData\Local\Temp/ipykernel_20128/1788599657.py in coins(lis)
#       4     for i in range(1,length):
#       5         count = 0
# ----> 6         for index,num in enumerate(lis):
#       7             if count == i:
#       8                 lis[index] = 1-num
#
# ~\AppData\Local\Temp/ipykernel_20128/1788599657.py in coins(lis)
#       4     for i in range(1,length):
#       5         count = 0
# ----> 6         for index,num in enumerate(lis):
#       7             if count == i:
#       8                 lis[index] = 1-num
#
# _pydevd_bundle\pydevd_cython_win32_39_64.pyx in _pydevd_bundle.pydevd_cython_win32_39_64.SafeCallWrapper.__call__()
#
# ...

# %%
head = []
for index, num in enumerate(l):
    if num == 0:
        head.append(index+1)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144, 169, 196, 225, 256, 289, 324, 361, 400, 441, 484, 529, 576, 625, 676, 729, 784, 841, 900, 961]
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144, 169, 196, 225, 256, 289, 324, 361, 400, 441, 484, 529, 576, 625, 676, 729, 784, 841, 900, 961]
# True

# %%
values = [[1000,0],[500,500],[501,499],[417,583],[453,547],[451,549],[465,535],[518,482],[477,523],[509,491],[507,493],[510,490],[516,484],[529,471],[537,463],[509,491],[513,487],[524,476],[526,474],[544,456],[545,455],[556,444],[559,441],[554,446],[552,448],[560,440],[561,439],[570,430],[558,442],[553,447],[535,465],[538,462],[528,472],[531,469],[527,473],[528,472],[511,489],[517,483],[518,482],[521,479],[505,495],[504,496],[489,511],[487,513],[491,509],[506,494],[493,507],[493,507],[491,509],[501,499],[502,498],[501,499],[491,509],[485,515],[485,515],[486,514],[487,513],[500,500],[492,508],[496,504],[488,512],[500,500],[497,503],[492,508],[495,505],[500,500],[492,508],[488,512],[488,512],[486,514],[478,522],[483,517],[476,524],[485,515],[482,518],[479,521],[477,523],[479,521],[473,527],[477,523],[475,525],[483,517],[477,523],[482,518],[483,517],[490,510],[489,511],[490,510],[485,515],[482,518],[480,520],[478,522],[476,524],[482,518],[482,518],[480,520],[476,524],[480,520],[480,520],[476,524],[473,527],[474,526],[471,529],[472,528],[471,529],[476,524],[473,527],[470,530],[467,533],[468,532],[467,533],[471,529],[467,533],[467,533],[469,531],[469,531],[467,533],[471,529],[469,531],[471,529],[463,537],[467,533],[465,535],[465,535],[469,531],[470,530],[467,533],[470,530],[469,531],[470,530],[467,533],[468,532],[465,535],[470,530],[469,531],[470,530],[467,533],[468,532],[465,535],[466,534],[465,535],[470,530],[468,532],[470,530],[470,530],[474,526